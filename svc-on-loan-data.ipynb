# %% [markdown]
# <a href="https://www.kaggle.com/code/tusharaggarwal27/svc-on-loan-data?scriptVersionId=116329884" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:20px;
#            background-color:#F5DEB3;
#            font-size:170%;
#            font-family:Helvetica, Sans-Serif;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#           text-align: center;
#           font-size:150%;
#           color:blue;">
#            💹🤖💹SVC on Loan Data💹🤖💹
#
# </p>
# <style>
#         h1{text-align: center;}
# </style>
#
# </div>

# %% [markdown]
# <p style="font-family:cursive; font-size:18px; color:'darkcyan';">I brewed this notebook from scratch, If this notebook helped, please consider upvoting and cite me if sharing ,Thank you!</p>
#
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:18px;border-radius:20px">
#     <a href="https://www.linkedin.com/in/tusharaggarwalinseec/" target="_blank">Lets connect on LinkedIn!</a>
#
#    </p>
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:18px;border-radius:20px">
# <a href="https://github.com/tushar2704" target="_blank">Follow me on Github too!</a> </p>
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:18px;border-radius:20px">
#     <a href="https://medium.com/@tushar_aggarwal" target="_blank">Also checkout my Medium posts!</a>
#
#    </p>

# %% [markdown]
# <div class="alert alert-info" role="alert" style="font-size:17px;border-radius:20px">
#     <b>In this project, I am using SVM algorithm on Loan Approval data to uncover based on given features whether the loan will get approved or not,</b>
#
# </div>
# <div class="alert alert-info" role="alert" style="font-size:15px;border-radius:20px">
#     <b>Some things to note:</b>
#     <br><br>SVM is the Supervised Machine Learning algorithm used for both classification, regression. But mostly preferred for classification, hence in this notebook also i am using for classification,
#     <br><br>
#     Given a dataset, the algorithm tries to divide the data using hyperplanes and then makes the predictions. SVM is a non-probabilistic linear classifier. While other classifiers, when classifying, predict the probability of a data point to belong to one group or the another, SVM directly says to which group the datapoint belongs to without using any probability calculation.
#     <br><br>
#     <a href="https://scikit-learn.org/stable/modules/svm.html" target="_blank">For more on SVM click here!</a>
# </div>

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Importing the required Libraries
#
#    </p>

# %%
#Basic liabraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Loading the Loan data
#     <br><a href="https://www.kaggle.com/datasets/tusharaggarwal27/loan-dataset" target="_blank">Get yours here!</a>
#    </p>

# %%
#Loading into the dataframe named 'loan_data'
loan_data=pd.read_csv("/kaggle/input/loan-dataset/loan_approved.csv")

#Reviewing some top rows to check
loan_data.head()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now some basic checks
#
#    </p>

# %%
#Using describe with include="all"
loan_data.describe(include='all')

# %%
#Using describe with include="O" Only for Categorical data
loan_data.describe(include='O')

# %%
#Using info to check metadata
loan_data.info()

# After seeing info ,some cleaning is required

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now, lets start with Exploratory Data Analysis(EDA) part
#
#    </p>

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now, lets start Bivariate Analysis
#
#    </p>

# %%
#Importing Autoviz 
# !pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class #Instantiate the AutoViz class
AV = AutoViz_Class()
# %matplotlib inline

# %%
filename = ""
sep=","
visual=AV.AutoViz(
    filename,
    sep=',',
    depVar='',
    dfte=loan_data,
    header=0,
    verbose=0,
    lowess=False,
    chart_format='svg',
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir=None)

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">After going through most usefull ones, taking next steps
#
#    </p>

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Data preprocessing Pipeline
#
#    </p>

# %%
#Checking for missing values and sorting them
loan_data.isnull().sum().sort_values(ascending=False)
#loan_data.shape

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Preprocessing for Categorical dtype
#
#    </p>

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Gender' column
#
#    </p>

# %%
#For Gender columns all the rows with null value
loan_data.loc[loan_data['Gender'].isnull()==True]

#Checking for Distribution for both labels in Gender
loan_data.Gender.value_counts()

# %%
#Checking for % of value missing for Gender in loan_data
loan_data['Gender'].isnull().sum() / len(loan_data)*100
#2 % data is missing

# %%
#Coutplot for Gender and target
sns.countplot(x="Gender", hue='Loan_Status (Approved)', data=loan_data)

# %%
#Based on above , as majority of borrowers are male , imputing the missing value as male, ie mode or mmost frequent
loan_data.loc[loan_data['Gender'].isnull()==True,"Gender"]='Male'

#Checking for changes
loan_data['Gender'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Dependents' column
#
#    </p>

# %%
#Checking 
loan_data.loc[loan_data['Dependents'].isnull()==True]

#Checking for %
loan_data['Dependents'].isnull().sum() / len(loan_data)*100


#Checking for distribution
loan_data['Dependents'].value_counts()

#Countplot for Dependents
sns.countplot(x='Dependents',hue='Loan_Status (Approved)', data=loan_data)

# %%
pd.crosstab(loan_data['Dependents'], loan_data['Loan_Status (Approved)'])

# %%
#Based on above as Dependent feature is important and as number of Dependents increase,chances of approval decreases
#To avoid costly mistake of unrecoverable loan ,imputing missing with 3+ , to away from these application

loan_data.loc[loan_data['Dependents'].isnull()==True, 'Dependents']='3+'

#checking now for changes made
loan_data['Dependents'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Married' column
#
#    </p>

# %%
#Checking
loan_data.loc[loan_data['Married'].isnull()==True]

#Checking for %
loan_data['Married'].isnull().sum() / len(loan_data) *100

#Checking for distribution
loan_data['Married'].value_counts()

#Countsplot for Married 
sns.countplot(x='Married',hue='Loan_Status (Approved)', data=loan_data)

# %%
#Based on above, more married status borrower are in approval range, therefore imputing with yes

loan_data.loc[loan_data['Married'].isnull()==True,'Married']='Yes'

#Checking for changes
loan_data['Married'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Self_Employed' column
#
#    </p>

# %%
#Checking
loan_data.loc[loan_data['Self_Employed'].isnull()==True]

#Checking for %
loan_data['Self_Employed'].isnull().sum() /len(loan_data)*100

#Cheking for distribution
loan_data['Self_Employed'].value_counts()

#Countsplot for "Self_Employed"
sns.countplot(x='Self_Employed', hue='Loan_Status (Approved)', data=loan_data)

# %%
#By analysing above and as loan are risky when borrower are self employed, thereby imputing by "No"

loan_data.loc[loan_data['Self_Employed'].isnull()==True,'Self_Employed']="No"

#checking for changes
loan_data['Self_Employed'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Preprocessing for Numerical dtype
#
#    </p>

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'LoanAmount' column
#
#    </p>

# %%
#Plotting histogram
loan_data['LoanAmount'].hist()
plt.show()

# %%
#Since,the data is skewed, is better to replace NaN with median values of LoanAmount.
#Its recommended to use mean for NaN when data is symmetrical

#Checking the median value for 'LoanAmount'
np.median(loan_data['LoanAmount'].dropna(axis=0))
#result is 128.0

#Nowreplacing the NaN in LoanAmount column with the meadin , i.e. 128.0
loan_data.loc[loan_data['LoanAmount'].isnull()==True, 'LoanAmount']=128.0

#or loan_data.loc[loan_data['LoanAmount'].isnull()==True, 'LoanAmount']=np.median(loan_data['LoanAmount'].dropna(axis=0))

#Checking for changes
loan_data['LoanAmount'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Loan_Amount_Term' column
#
#    </p>

# %%
#Plotting the histogram 
loan_data['Loan_Amount_Term'].hist()

# %%
#Since this is also skewed ,using median to replace NaN

loan_data.loc[loan_data['Loan_Amount_Term'].isnull()==True,'Loan_Amount_Term']=np.median(loan_data['Loan_Amount_Term'].dropna(axis=0))
    

#Checking for changes now
loan_data['Loan_Amount_Term'].isnull().sum()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">For 'Credit_History' column
#
#    </p>

# %%
#Checking of distribution
loan_data['Credit_History'].value_counts()

#Plotting countplot
sns.countplot(x='Credit_History',hue='Loan_Status (Approved)', data=loan_data)

# %%
#As '0' here indicates that previous creditline was faulty in payments or loan was not ever taken,
#Its better to impute with '0' as our model should reject that risky loan before hand ,otherwise underwriter would have take timejust to rejcet application

#Replacing the NaN in Credit_Historywith 0
loan_data.loc[loan_data['Credit_History'].isnull()==True,'Credit_History']=0

#Cheking for changes now
loan_data['Credit_History'].isnull().sum()

# %%
#Now checking for loan_data for NaN
loan_data.info()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now, handling the Categorical dtype
#
#    </p>

# %%
#Using the label Encoder to convert Categorical data into numerical/binary(in some cases), for the model building

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #Creating object

#Now using le.fit_transform

loan_data['Gender'] =le.fit_transform(loan_data['Gender'])
loan_data['Married']=le.fit_transform(loan_data['Married'])
loan_data['Education']=le.fit_transform(loan_data['Education'])
loan_data['Property_Area']=le.fit_transform(loan_data['Property_Area'])
loan_data['Loan_Status (Approved)']=le.fit_transform(loan_data['Loan_Status (Approved)']) # Our target feature
loan_data['Dependents']=le.fit_transform(loan_data['Dependents'])
loan_data['Self_Employed']=le.fit_transform(loan_data['Self_Employed'])

# %%
#Finanlly checking loan_data
loan_data.info(), 
loan_data.head()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now, Scaling the data
#
#    </p>

# %%
#As scaling need to be done only for continous data
from sklearn.preprocessing import MinMaxScaler #or use here X_Scale=(X-Xmin)/(Xmax-Xmin) 
scale=MinMaxScaler() #creating the object, toconvert into Standard Normal Distribution

loan_data[['ApplicantIncome','CoapplicantIncome','LoanAmount']] = scale.fit_transform(loan_data[['ApplicantIncome','CoapplicantIncome','LoanAmount']])

#Cheking for transformed data
loan_data.head()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Now, Feature Selection
#
#    </p>

# %%
#Removing the redundant column
loan_data.drop('Loan_ID', axis=1,inplace=True)
#loan_data.head()

# %%
#Checking for highly correlated features
corr_data= loan_data[['ApplicantIncome','CoapplicantIncome','LoanAmount']]

#Plotting heatmap  to see correlation
sns.heatmap(corr_data.corr(), annot=True)

#There are no string relationship among the sacled numerical data
corr_data.describe()

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:21px;border-radius:20px">
#     <b>Model Creation</b>
#
#    </p>

# %%
#Defining the Dependent and Target variables
X = loan_data.iloc[:,:-1]
y=loan_data['Loan_Status (Approved)']

# %%
#Creating Training and Testing variables
from sklearn.model_selection import train_test_split

X_train,X_test,y_train, y_test =train_test_split(X, y, random_state=3)

# %%
#Balancing the training data to reduce biasness of output towards majority classs
loan_data['Loan_Status (Approved)'].value_counts()

# %%
#instaling the imblearn package
# !pip install imblearn
from imblearn.over_sampling import SMOTE

#Creating object
smote=SMOTE()

# %%
X_smote, y_smote = smote.fit_resample(X_train, y_train)

#Checking to balance
from collections import Counter
print('Actual Classes', Counter(y_train))
print('SMOTE Classes', Counter(y_smote))

# %%
#SVM Classifier
from sklearn.svm import SVC #SVC is Support Vector Classifier
svc_base = SVC() #base model with default parameters, creating object

#Fitting the training data
svc_base.fit(X_smote, y_smote)

# %%
#Predicting the output for X_test
y_hat=svc_base.predict(X_test)
y_hat

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Evaluation of Base model
#
#    </p>

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, f1_score
acc= accuracy_score(y_test, y_hat)
print(acc)
print(classification_report(y_test, y_hat))

#recall of 0 in not okay

# %%
#Confusion matrix
cm=pd.crosstab(y_test, y_hat)
cm

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">Checking for Cross Validation Score
#
#    </p>

# %%
from sklearn.model_selection import cross_val_score

cval=cross_val_score(svc_base, X, y, cv=5, scoring='f1')
print(cval)
print("Cross Validation Score", cval.mean())
print("std", cval.std())

#std of <0.05 is good

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">
# Model Hyperparameter tunning
#    </p>

# %%
#GrideSearch
from sklearn.model_selection import GridSearchCV

#Defining the parameters range
param_grid ={'C':[0.1,1,10,100,1000],
            'gamma':[1,0.1, 0.01,0.001,0.0001],
             'random_state':(list(range(1,20)))}

model=SVC()
grid_search = GridSearchCV(model,param_grid, refit=True,verbose=2, scoring='f1', cv=10 )

#Fitting the model for GridSearch
grid_search.fit(X,y) #Use

# %%
#Printing best params after tunning
print(grid_search.best_params_)

# %%
#Priniting how our model looks after HyperParameter tunning
print(grid_search.best_estimator_)

# %%
#clf=SVC(C=100, gamma=0.001, random_state=42) ##0.1
svc_clf= SVC(C=10, gamma=0.01, random_state=1) ##0.1

# %%
#Fitting svc_clf
svc_clf.fit(X_smote,y_smote)

#Predicitng svc_clf
y_clf = svc_clf.predict(X_test)

# %%
#Prinitng classification report on svc_clf
print(classification_report(y_test, y_clf))

# %%
#Confusion matrix
cm=pd.crosstab(y_test,y_clf)
cm

# %%
print(f1_score(y_test, y_clf))

# %%
#Scores after GridSearch
scores_clf = cross_val_score(svc_clf, X,y,cv=10, scoring='f1')
print(scores_clf)
print("Cross Validation Score:", scores_clf.mean())
print("Std:", scores_clf.std()) #std of <0.05 is good

# %% [markdown]
# <p style="width: 700px;padding: 20px;background: papayawhip;border-radius:10px;font-size:17px;border-radius:20px">
# F1 scoreimporved, but recallis still lagging, Next step is to try pd.get_dummies, and StandardSclaer to see improvement
#    </p>
